# %%
# from xyz2graph import MolGraph, to_networkx_graph, to_plotly_figure
# import networkx as nx
# from karateclub import Graph2Vec
# import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data_frame=pd.read_csv('CM5.csv')
data_frame=data_frame.iloc[:128,2:]
data_frame
# Out:
#      covlent_total  bond_length_origin  distance_matrix_origin  \
# 0           201.00                1.42                  302.00
# 1           206.00                1.88                  228.00
# 2           206.00                1.88                  272.00
# 3           206.00                1.88                  261.00
# 4           204.00                1.42                  258.00
# ..             ...                 ...                     ...
# 123         433.00                1.93                  865.00
# 124         434.00                1.93                  728.00
# 125         432.90                1.65                  720.00
# 126         437.20                1.86                  720.00
# 127         439.20                1.93                  728.00
#
#      position_origin  EF1  EF2  dEF  electronegativity_1  electronegativity_2  \
# 0             121.92 0.15 0.28 0.13                 1.83                 2.04
# 1             112.78 0.15 0.28 0.13                 1.83                 2.04
# 2             121.55 0.15 0.28 0.13                 1.83                 2.04
# 3             119.28 0.15 0.28 0.13                 1.83                 2.04
# 4             113.15 0.15 1.26 1.11                 1.83                 2.55
# ..               ...  ...  ...  ...                  ...                  ...
# 123           252.01 0.15 0.35 0.20                 1.83                 2.67
# 124           234.63 0.15 0.63 0.48                 1.83                 2.79
# 125           225.99 0.15 0.96 0.81                 1.83                 3.31
# 126           225.99 0.15 1.03 0.88                 1.83                 2.99
# 127           234.62 0.15 1.08 0.93                 1.83                 4.45
#
#      electronegativity_3  electronegativity_2-electronegativity_1  \
# 0                   2.55                                     0.21
# 1                   2.55                                     0.21
# 2                   2.55                                     0.21
# 3                   2.55                                     0.21
# 4                   2.55                                     0.72
# ..                   ...                                      ...
# 123                 2.55                                     0.84
# 124                 2.55                                     0.96
# 125                 2.55                                     1.48
# 126                 2.55                                     1.16
# 127                 2.55                                     2.62
#
#      electronegativity_3-electronegativity_2  Ntotal  Rcov1_pm  Rvoc2_pm  \
# 0                                       0.51   60.00    125.00     82.00
# 1                                       0.51   59.00    125.00     82.00
# 2                                       0.51   59.00    125.00     82.00
# 3                                       0.51   60.00    125.00     82.00
# 4                                       0.00   60.00    125.00     77.00
# ..                                       ...     ...       ...       ...
# 123                                    -0.12  119.00    125.00     75.50
# 124                                    -0.24  119.00    125.00     75.00
# 125                                    -0.76  120.00    125.00     80.33
# 126                                    -0.44  119.00    125.00     78.50
# 127                                    -1.90  119.00    125.00     80.75
#
#      d(R1-R2)        IE  NVA  Ncor  H-L gap
# 0       43.00   8298.00 5.00  3.00     0.02
# 1       43.00   8298.00 5.00  4.00     0.02
# 2       43.00   8298.00 5.00  4.00     0.01
# 3       43.00   8298.00 5.00  4.00     0.01
# 4       48.00 112603.00 6.00  3.00     0.01
# ..        ...       ...  ...   ...      ...
# 123     49.50 102895.00 6.25  4.00     0.01
# 124     50.00 128972.00 6.50  4.00     0.01
# 125     44.67 139234.00 8.30  3.00     0.04
# 126     46.50 132576.00 7.30  4.00     0.04
# 127     44.25 138471.00 7.80  4.00     0.03
#
# [128 rows x 20 columns]

# %%
# load graph vector

graph_vector=np.load('graph_vector_for_CM5.npy')

# %%
data_frame.insert(0,'graph_vector_1',graph_vector[:,0])
data_frame.insert(1,'graph_vector_2',graph_vector[:,1])
data_frame.insert(2,'graph_vector_3',graph_vector[:,2])
data_frame
# Out:
#      graph_vector_1  graph_vector_2  graph_vector_3  covlent_total  \
# 0              0.69            1.13            0.45         201.00
# 1              0.39            1.09            0.05         206.00
# 2              0.38            1.18           -0.10         206.00
# 3              0.23            1.05            0.42         206.00
# 4              0.31            1.11            0.41         204.00
# ..              ...             ...             ...            ...
# 123            0.32            0.85            0.09         433.00
# 124            0.20            0.91            0.27         434.00
# 125            0.52            0.63           -0.05         432.90
# 126            0.13            0.77            0.40         437.20
# 127            0.19            0.54            0.44         439.20
#
#      bond_length_origin  distance_matrix_origin  position_origin  EF1  EF2  \
# 0                  1.42                  302.00           121.92 0.15 0.28
# 1                  1.88                  228.00           112.78 0.15 0.28
# 2                  1.88                  272.00           121.55 0.15 0.28
# 3                  1.88                  261.00           119.28 0.15 0.28
# 4                  1.42                  258.00           113.15 0.15 1.26
# ..                  ...                     ...              ...  ...  ...
# 123                1.93                  865.00           252.01 0.15 0.35
# 124                1.93                  728.00           234.63 0.15 0.63
# 125                1.65                  720.00           225.99 0.15 0.96
# 126                1.86                  720.00           225.99 0.15 1.03
# 127                1.93                  728.00           234.62 0.15 1.08
#
#      dEF  ...  electronegativity_2-electronegativity_1  \
# 0   0.13  ...                                     0.21
# 1   0.13  ...                                     0.21
# 2   0.13  ...                                     0.21
# 3   0.13  ...                                     0.21
# 4   1.11  ...                                     0.72
# ..   ...  ...                                      ...
# 123 0.20  ...                                     0.84
# 124 0.48  ...                                     0.96
# 125 0.81  ...                                     1.48
# 126 0.88  ...                                     1.16
# 127 0.93  ...                                     2.62
#
#      electronegativity_3-electronegativity_2  Ntotal  Rcov1_pm  Rvoc2_pm  \
# 0                                       0.51   60.00    125.00     82.00
# 1                                       0.51   59.00    125.00     82.00
# 2                                       0.51   59.00    125.00     82.00
# 3                                       0.51   60.00    125.00     82.00
# 4                                       0.00   60.00    125.00     77.00
# ..                                       ...     ...       ...       ...
# 123                                    -0.12  119.00    125.00     75.50
# 124                                    -0.24  119.00    125.00     75.00
# 125                                    -0.76  120.00    125.00     80.33
# 126                                    -0.44  119.00    125.00     78.50
# 127                                    -1.90  119.00    125.00     80.75
#
#      d(R1-R2)        IE  NVA  Ncor  H-L gap
# 0       43.00   8298.00 5.00  3.00     0.02
# 1       43.00   8298.00 5.00  4.00     0.02
# 2       43.00   8298.00 5.00  4.00     0.01
# 3       43.00   8298.00 5.00  4.00     0.01
# 4       48.00 112603.00 6.00  3.00     0.01
# ..        ...       ...  ...   ...      ...
# 123     49.50 102895.00 6.25  4.00     0.01
# 124     50.00 128972.00 6.50  4.00     0.01
# 125     44.67 139234.00 8.30  3.00     0.04
# 126     46.50 132576.00 7.30  4.00     0.04
# 127     44.25 138471.00 7.80  4.00     0.03
#
# [128 rows x 23 columns]

# %% [markdown]
# # ML

# %%
train_value=data_frame.iloc[:,:-1].values
target_value=data_frame.iloc[:,-1].values

# %% [markdown]
# ## normalization

# %%
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
minmax_scaler=preprocessing.MinMaxScaler()
train_value_scaler=minmax_scaler.fit_transform(train_value)

# %%
X_train_full,X_test,y_train_full,y_test=train_test_split(train_value_scaler,target_value,test_size=0.2,random_state=0)
X_train,X_valid,y_train,y_valid=train_test_split(X_train_full,y_train_full,test_size=0.2,random_state=42)
X_train.shape, X_valid.shape, X_test.shape,y_train.shape, y_valid.shape, y_test.shape,
# Out:
# ((81, 22), (21, 22), (26, 22), (81,), (21,), (26,))

# %% [markdown]
# ## Rough estimation

# %%
from lazypredict.Supervised import LazyRegressor
reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)
models, predictions = reg.fit(X_train_full, X_test, y_train_full, y_test)

print(models)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 41/41 [00:00<00:00, 65.99it/s]
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# KNeighborsRegressor                         -1.48       0.70  0.01        0.00
# ExtraTreesRegressor                         -1.79       0.66  0.01        0.06
# AdaBoostRegressor                           -2.62       0.57  0.01        0.03
# LGBMRegressor                               -3.07       0.51  0.01        0.01
# BaggingRegressor                            -3.36       0.48  0.01        0.01
# ExtraTreeRegressor                          -3.41       0.47  0.01        0.00
# HistGradientBoostingRegressor               -3.59       0.45  0.01        0.05
# RandomForestRegressor                       -3.62       0.45  0.01        0.08
# GradientBoostingRegressor                   -4.30       0.36  0.01        0.03
# NuSVR                                       -4.82       0.30  0.01        0.01
# OrthogonalMatchingPursuitCV                 -4.85       0.30  0.01        0.01
# LarsCV                                      -5.34       0.24  0.01        0.01
# LassoLarsCV                                 -5.34       0.24  0.01        0.01
# GammaRegressor                              -5.36       0.24  0.01        0.00
# OrthogonalMatchingPursuit                   -5.37       0.24  0.01        0.00
# TweedieRegressor                            -5.60       0.21  0.01        0.00
# BayesianRidge                               -5.66       0.20  0.01        0.00
# XGBRegressor                                -5.70       0.20  0.01        0.02
# RidgeCV                                     -5.87       0.18  0.02        0.00
# ElasticNetCV                                -6.04       0.16  0.02        0.08
# LassoCV                                     -6.04       0.16  0.02        0.07
# SGDRegressor                                -6.07       0.15  0.02        0.00
# LassoLarsIC                                 -6.15       0.14  0.02        0.00
# Ridge                                       -6.29       0.13  0.02        0.00
# LinearRegression                            -6.43       0.11  0.02        0.00
# TransformedTargetRegressor                  -6.43       0.11  0.02        0.00
# Lars                                        -6.43       0.11  0.02        0.00
# HuberRegressor                              -6.88       0.05  0.02        0.01
# PoissonRegressor                            -7.24       0.01  0.02        0.00
# DummyRegressor                              -7.41      -0.01  0.02        0.00
# ElasticNet                                  -7.41      -0.01  0.02        0.00
# Lasso                                       -7.41      -0.01  0.02        0.00
# LassoLars                                   -7.41      -0.01  0.02        0.00
# DecisionTreeRegressor                       -8.99      -0.20  0.02        0.00
# LinearSVR                                  -10.56      -0.39  0.02        0.01
# GaussianProcessRegressor                   -11.80      -0.54  0.02        0.00
# SVR                                        -14.26      -0.83  0.02        0.00
# KernelRidge                                -17.86      -1.26  0.02        0.00
# PassiveAggressiveRegressor                 -20.28      -1.55  0.03        0.00
# RANSACRegressor                           -195.40     -22.57  0.08        0.03
# MLPRegressor                              -255.75     -29.81  0.09        0.02

# %% [markdown]
# ## ExtraTreesRegressor

# %%
from sklearn.model_selection import GridSearchCV, RepeatedKFold, cross_val_score,cross_val_predict,KFold
from sklearn.metrics import make_scorer,mean_squared_error,r2_score
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.svm import LinearSVR, SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.preprocessing import PolynomialFeatures,MinMaxScaler,StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor

# %%
def rmse(y_true, y_pred):
    diff = y_pred - y_true
    sum_sq = sum(diff**2)    
    n = len(y_pred)   
    
    return np.sqrt(sum_sq/n)

def mse(y_ture,y_pred):
    return mean_squared_error(y_ture,y_pred)

def train_model(model, param_grid=[], X_train=[], y_train=[], X_test=[], y_test=[],
                splits=5, repeats=5):
    # create cross-validation method
    rkfold = RepeatedKFold(n_splits=splits, n_repeats=repeats,random_state=42)
    # perform a grid search if param_grid given
    if len(param_grid)>0:
        # setup grid search parameters
        gsearch = GridSearchCV(model, param_grid, cv=rkfold,
                               scoring="neg_mean_squared_error",
                               verbose=1, return_train_score=True)
# search the grid
        gsearch.fit(X_train,y_train)

        # extract best model from the grid
        model = gsearch.best_estimator_        
        best_idx = gsearch.best_index_
        best_parameter=gsearch.best_params_
# get cv-scores for best model
        grid_results = pd.DataFrame(gsearch.cv_results_)       
        cv_mean = abs(grid_results.loc[best_idx,'mean_test_score'])
        cv_std = grid_results.loc[best_idx,'std_test_score']
# no grid search, just cross-val score for given model    
    else:
        grid_results = []
        cv_results = cross_val_score(model, X_train,y_train, scoring="neg_mean_squared_error", cv=rkfold)
        cv_mean = abs(np.mean(cv_results))
        cv_std = np.std(cv_results)
    
    # combine mean and std cv-score in to a pandas series
    cv_score = pd.Series({'mean':cv_mean,'std':cv_std})

    # predict y using the fitted model
    y_pred_test = model.predict(X_test)
    y_pred_train = model.predict(X_train)
    # print stats on model performance         
    print('----------------------')
    print(model)
    print('best parameters:',best_parameter)
    print('----------------------')
    print('train r2_score=',model.score(X_train,y_train))
    print('test r2_score=',model.score(X_test,y_test))
    print('rmse=',rmse(y_test, y_pred_test))
    print('mse=',mse(y_test, y_pred_test))
    print('cross_val: mean=',cv_mean,', std=',cv_std)
#     y_pred = pd.Series(y_pred,index=y.index)
#     resid = y_test - y_pred
#     mean_resid = resid.mean()
#     std_resid = resid.std()
    
    plt.figure(figsize=(6,5))
#     ax_121 = plt.subplot(1,2,1)
    plt.scatter(y_test,y_pred_test,label='test data')
    plt.scatter(y_train,y_pred_train,label='train data')
    plt.plot(target_value,target_value,'-k')
    plt.legend()
    plt.xlabel('H-L gap')
    plt.ylabel('predicted H-L gap');
    plt.title('test: r^2 = {:.3f}'.format(model.score(X_test,y_test)))
    plt.show()
#     ax_122=plt.subplot(1,2,2)
#     plt.plot(y_train,y_pred_train,'.')
#     plt.plot(y_train,y_train,'--b')
#     plt.xlabel('y_train')
#     plt.ylabel('y_pred_train')
#     plt.title('r^2 = {:.3f}'.format(model.score(X_train,y_train)))
#     plt.plot(y_test,y_test-y_pred,'.')
#     plt.xlabel('y_test')
#     plt.ylabel('y_test - y_pred');
#     plt.title('std resid = {:.3f}'.format(std_resid))
    
 
    return model, cv_score, grid_results

# %%
# places to store optimal models and scores
opt_models = dict()
score_models = pd.DataFrame(columns=['mean','std'])

# no. k-fold splits
splits=5
# no. k-fold iterations
repeats=5

# %%
data_frame.iloc[:,:-1]
# Out:
#      graph_vector_1  graph_vector_2  graph_vector_3  covlent_total  \
# 0              0.69            1.13            0.45         201.00
# 1              0.39            1.09            0.05         206.00
# 2              0.38            1.18           -0.10         206.00
# 3              0.23            1.05            0.42         206.00
# 4              0.31            1.11            0.41         204.00
# ..              ...             ...             ...            ...
# 123            0.32            0.85            0.09         433.00
# 124            0.20            0.91            0.27         434.00
# 125            0.52            0.63           -0.05         432.90
# 126            0.13            0.77            0.40         437.20
# 127            0.19            0.54            0.44         439.20
#
#      bond_length_origin  distance_matrix_origin  position_origin  EF1  EF2  \
# 0                  1.42                  302.00           121.92 0.15 0.28
# 1                  1.88                  228.00           112.78 0.15 0.28
# 2                  1.88                  272.00           121.55 0.15 0.28
# 3                  1.88                  261.00           119.28 0.15 0.28
# 4                  1.42                  258.00           113.15 0.15 1.26
# ..                  ...                     ...              ...  ...  ...
# 123                1.93                  865.00           252.01 0.15 0.35
# 124                1.93                  728.00           234.63 0.15 0.63
# 125                1.65                  720.00           225.99 0.15 0.96
# 126                1.86                  720.00           225.99 0.15 1.03
# 127                1.93                  728.00           234.62 0.15 1.08
#
#      dEF  ...  electronegativity_3  electronegativity_2-electronegativity_1  \
# 0   0.13  ...                 2.55                                     0.21
# 1   0.13  ...                 2.55                                     0.21
# 2   0.13  ...                 2.55                                     0.21
# 3   0.13  ...                 2.55                                     0.21
# 4   1.11  ...                 2.55                                     0.72
# ..   ...  ...                  ...                                      ...
# 123 0.20  ...                 2.55                                     0.84
# 124 0.48  ...                 2.55                                     0.96
# 125 0.81  ...                 2.55                                     1.48
# 126 0.88  ...                 2.55                                     1.16
# 127 0.93  ...                 2.55                                     2.62
#
#      electronegativity_3-electronegativity_2  Ntotal  Rcov1_pm  Rvoc2_pm  \
# 0                                       0.51   60.00    125.00     82.00
# 1                                       0.51   59.00    125.00     82.00
# 2                                       0.51   59.00    125.00     82.00
# 3                                       0.51   60.00    125.00     82.00
# 4                                       0.00   60.00    125.00     77.00
# ..                                       ...     ...       ...       ...
# 123                                    -0.12  119.00    125.00     75.50
# 124                                    -0.24  119.00    125.00     75.00
# 125                                    -0.76  120.00    125.00     80.33
# 126                                    -0.44  119.00    125.00     78.50
# 127                                    -1.90  119.00    125.00     80.75
#
#      d(R1-R2)        IE  NVA  Ncor
# 0       43.00   8298.00 5.00  3.00
# 1       43.00   8298.00 5.00  4.00
# 2       43.00   8298.00 5.00  4.00
# 3       43.00   8298.00 5.00  4.00
# 4       48.00 112603.00 6.00  3.00
# ..        ...       ...  ...   ...
# 123     49.50 102895.00 6.25  4.00
# 124     50.00 128972.00 6.50  4.00
# 125     44.67 139234.00 8.30  3.00
# 126     46.50 132576.00 7.30  4.00
# 127     44.25 138471.00 7.80  4.00
#
# [128 rows x 22 columns]

# %%
model = 'ExtraTreesRegressor'
opt_models[model] = ExtraTreesRegressor(random_state=64)

param_grid = {'n_estimators': np.arange(20,150,10),
#               'learning_rate':[0.8,0.9,1,1.1,1.2],
#               'loss':['linear', 'square', 'exponential']
             }

opt_models[model], cv_score,grid_results = train_model(opt_models[model], param_grid=param_grid, 
                                            X_train=X_train_full,y_train=y_train_full,
                                            X_test=X_test, y_test=y_test,splits=splits, repeats=1)

cv_score.name = model
score_models = score_models.append(cv_score)
# Out:
# Fitting 5 folds for each of 13 candidates, totalling 65 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# ----------------------
# ExtraTreesRegressor(n_estimators=140, random_state=64)
# best parameters: {'n_estimators': 140}
# ----------------------
# train r2_score= 1.0
# test r2_score= 0.6815371594145949
# rmse= 0.009371453703130042
# mse= 8.782414450990978e-05
# cross_val: mean= 0.00015493223755702617 , std= 5.480754399809963e-05
# [Parallel(n_jobs=1)]: Done  65 out of  65 | elapsed:    2.7s finished

# %%
def rf_feat_importance(m, df):
    return pd.DataFrame({'cols':df.columns, 'imp':m.feature_importances_}
                       ).sort_values('imp', ascending=False)

model = 'ExtraTreesRegressor'
fi=rf_feat_importance(opt_models[model],data_frame.iloc[:,:-1])
fi
# Out:
#                                        cols  imp
# 8                                       EF2 0.17
# 9                                       dEF 0.16
# 21                                     Ncor 0.13
# 4                        bond_length_origin 0.09
# 19                                       IE 0.06
# 0                            graph_vector_1 0.05
# 1                            graph_vector_2 0.04
# 3                             covlent_total 0.04
# 18                                 d(R1-R2) 0.04
# 5                    distance_matrix_origin 0.04
# 6                           position_origin 0.04
# 15                                   Ntotal 0.04
# 2                            graph_vector_3 0.03
# 14  electronegativity_3-electronegativity_2 0.02
# 13  electronegativity_2-electronegativity_1 0.02
# 11                      electronegativity_2 0.02
# 20                                      NVA 0.02
# 17                                 Rvoc2_pm 0.02
# 7                                       EF1 0.00
# 10                      electronegativity_1 0.00
# 12                      electronegativity_3 0.00
# 16                                 Rcov1_pm 0.00

# %%
def plot_fi(fi):
    return fi.plot('cols', 'imp', 'barh', figsize=(12,7), legend=False)
plot_fi(fi)
