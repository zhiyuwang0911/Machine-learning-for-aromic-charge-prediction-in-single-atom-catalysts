# %%
# from xyz2graph import MolGraph, to_networkx_graph, to_plotly_figure
# import networkx as nx
# from karateclub import Graph2Vec
# import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data_frame=pd.read_csv('Bader_opt.csv')
data_frame=data_frame.iloc[:,1:]
data_frame
# Out:
#      bond_length_opt  distance_matrix_opt  position_opt       EF1       EF2  \
# 0           1.915592                  302    130.650075  0.153236  0.279723
# 1           1.959135                  228    113.739192  0.153236  0.279723
# 2           1.829786                  277    121.903527  0.153236  0.279723
# 3           1.916395                  286    120.467228  0.153236  0.279723
# 4           1.694909                  258    114.971657  0.153236  1.262123
# ..               ...                  ...           ...       ...       ...
# 123         1.724187                  920    249.887436  0.153236  0.350450
# 124         1.729807                  856    248.565936  0.153236  0.631110
# 125         1.737068                  720    225.608554  0.153236  0.960740
# 126         1.865043                  720    225.618064  0.153236  1.028580
# 127         1.893422                  728    231.734081  0.153236  1.078333
#
# ...

# %%
# load graph vector
graph_vector=np.load('graph_vector_for_bader.npy')

# %%
data_frame.insert(0,'graph_vector_1',graph_vector[:,0])
data_frame.insert(1,'graph_vector_2',graph_vector[:,1])
data_frame.insert(2,'graph_vector_3',graph_vector[:,2])
data_frame
# Out:
#      graph_vector_1  graph_vector_2  graph_vector_3  bond_length_opt  \
# 0          0.462814        0.945878        0.664656         1.915592
# 1          0.061043        0.812702        0.480450         1.959135
# 2          0.117755        1.000821        0.240903         1.829786
# 3         -0.050917        0.693757        0.768513         1.916395
# 4          0.067833        0.853026        0.730543         1.694909
# ..              ...             ...             ...              ...
# 123        0.215889        0.833803        0.292267         1.724187
# 124       -0.063970        0.620186        0.616254         1.729807
# 125        0.373830        0.559300        0.300599         1.737068
# 126       -0.040683        0.562256        0.643803         1.865043
# 127       -0.030182        0.281646        0.654361         1.893422
#
#      distance_matrix_opt  position_opt       EF1       EF2       dEF  \
# ...

# %% [markdown]
# # ML

# %%
train_value=data_frame.iloc[:,:-1].values
target_value=data_frame.iloc[:,-1].values

# %% [markdown]
# ## normalization

# %%
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
minmax_scaler=preprocessing.MinMaxScaler()
train_value_scaler=minmax_scaler.fit_transform(train_value)

# %%
X_train_full,X_test,y_train_full,y_test=train_test_split(train_value_scaler,target_value,test_size=0.18,random_state=0)
X_train,X_valid,y_train,y_valid=train_test_split(X_train_full,y_train_full,test_size=0.18,random_state=42)
X_train.shape, X_valid.shape, X_test.shape,y_train.shape, y_valid.shape, y_test.shape,
# Out:
# ((85, 21), (19, 21), (24, 21), (85,), (19,), (24,))

# %% [markdown]
# ## Rough estimation

# %%
from lazypredict.Supervised import LazyRegressor
reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)
models, predictions = reg.fit(X_train_full, X_test, y_train_full, y_test)

print(models)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████| 41/41 [00:00<00:00, 65.08it/s]
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# LGBMRegressor                               -0.39       0.88  0.09        0.01
# HistGradientBoostingRegressor               -0.47       0.87  0.09        0.05
# BaggingRegressor                            -1.07       0.82  0.11        0.01
# RandomForestRegressor                       -1.29       0.80  0.11        0.07
# ExtraTreesRegressor                         -1.75       0.76  0.12        0.05
# AdaBoostRegressor                           -1.88       0.75  0.12        0.04
# OrthogonalMatchingPursuitCV                 -2.13       0.73  0.13        0.01
# GradientBoostingRegressor                   -2.18       0.72  0.13        0.03
# HuberRegressor                              -2.39       0.70  0.14        0.01
# ...

# %% [markdown]
# ## AdaBoostRegressor

# %%
from sklearn.model_selection import GridSearchCV, RepeatedKFold, cross_val_score,cross_val_predict,KFold
from sklearn.metrics import make_scorer,mean_squared_error,r2_score,mean_absolute_error
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.svm import LinearSVR, SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.preprocessing import PolynomialFeatures,MinMaxScaler,StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
import lightgbm as lgb
from sklearn.model_selection import GridSearchCV

# %%
def rmse(y_true, y_pred):
    diff = y_pred - y_true
    sum_sq = sum(diff**2)    
    n = len(y_pred)   
    
    return np.sqrt(sum_sq/n)

def mse(y_ture,y_pred):
    return mean_squared_error(y_ture,y_pred)

def train_model(model, param_grid=[], X_train=[], y_train=[], X_test=[], y_test=[],
                splits=5, repeats=5):
    # create cross-validation method
    rkfold = RepeatedKFold(n_splits=splits, n_repeats=repeats,random_state=42)
    # perform a grid search if param_grid given
    if len(param_grid)>0:
        # setup grid search parameters
        gsearch = GridSearchCV(model, param_grid, cv=rkfold,
                               scoring="neg_mean_squared_error",
                               verbose=1, return_train_score=True)
# search the grid
        gsearch.fit(X_train,y_train)

        # extract best model from the grid
        model = gsearch.best_estimator_        
        best_idx = gsearch.best_index_
        best_parameter=gsearch.best_params_
# get cv-scores for best model
        grid_results = pd.DataFrame(gsearch.cv_results_)       
        cv_mean = abs(grid_results.loc[best_idx,'mean_test_score'])
        cv_std = grid_results.loc[best_idx,'std_test_score']
# no grid search, just cross-val score for given model    
    else:
        grid_results = []
        cv_results = cross_val_score(model, X_train,y_train, scoring="neg_mean_squared_error", cv=rkfold)
        cv_mean = abs(np.mean(cv_results))
        cv_std = np.std(cv_results)
    
    # combine mean and std cv-score in to a pandas series
    cv_score = pd.Series({'mean':cv_mean,'std':cv_std})

    # predict y using the fitted model
    y_pred_test = model.predict(X_test)
    y_pred_train = model.predict(X_train)
    # print stats on model performance         
    print('----------------------')
    print(model)
    print('best parameters:',best_parameter)
    print('----------------------')
    print('train r2_score=',model.score(X_train,y_train))
    print('test r2_score=',model.score(X_test,y_test))
    print('rmse=',rmse(y_test, y_pred_test))
    print('MAE:',mean_absolute_error(y_test, y_pred_test))
    print('mse=',mse(y_test, y_pred_test))
    print('cross_val: mean=',cv_mean,', std=',cv_std)
#     y_pred = pd.Series(y_pred,index=y.index)
#     resid = y_test - y_pred
#     mean_resid = resid.mean()
#     std_resid = resid.std()
    
    plt.figure(figsize=(6,5))
#     ax_121 = plt.subplot(1,2,1)
    plt.scatter(y_test,y_pred_test,label='test data')
    plt.scatter(y_train,y_pred_train,label='train data')
    plt.plot(target_value,target_value,'-k')
    plt.legend()
    plt.xlabel('observed bader charge')
    plt.ylabel('predicted bader charge');
    plt.title('test: r^2 = {:.3f}'.format(model.score(X_test,y_test)))
    plt.show()
#     ax_122=plt.subplot(1,2,2)
#     plt.plot(y_train,y_pred_train,'.')
#     plt.plot(y_train,y_train,'--b')
#     plt.xlabel('y_train')
#     plt.ylabel('y_pred_train')
#     plt.title('r^2 = {:.3f}'.format(model.score(X_train,y_train)))
#     plt.plot(y_test,y_test-y_pred,'.')
#     plt.xlabel('y_test')
#     plt.ylabel('y_test - y_pred');
#     plt.title('std resid = {:.3f}'.format(std_resid))
    
 
    return model, cv_score, grid_results, y_pred_train, y_pred_test, y_test, y_train

# %%
# places to store optimal models and scores
opt_models = dict()
score_models = pd.DataFrame(columns=['mean','std'])

# no. k-fold splits
splits=5
# no. k-fold iterations
repeats=5

# %%
data_frame.iloc[:,:-1]
# Out:
#      graph_vector_1  graph_vector_2  graph_vector_3  bond_length_opt  \
# 0              0.46            0.95            0.66             1.92
# 1              0.06            0.81            0.48             1.96
# 2              0.12            1.00            0.24             1.83
# 3             -0.05            0.69            0.77             1.92
# 4              0.07            0.85            0.73             1.69
# ..              ...             ...             ...              ...
# 123            0.22            0.83            0.29             1.72
# 124           -0.06            0.62            0.62             1.73
# 125            0.37            0.56            0.30             1.74
# 126           -0.04            0.56            0.64             1.87
# 127           -0.03            0.28            0.65             1.89
#
#      distance_matrix_opt  position_opt  EF1  EF2  dEF  electronegativity_1  \
# ...

# %%
w=np.array(y_test)
d = open('y_test_opt.txt', 'w')
for i in w:
    d.write('{:.5f}\n'.format(float(i)))
d.close()

# %%
DFT = np.array(target_value)
predict = np.concatenate((y_pred_train, y_pred_test))
index= np.concatenate ((train_index, test_index))
yy = np.array(list(zip(index,predict)))
value=yy[np.lexsort(np.fliplr(yy).T)]
value
conve=np.array(value)
y_predict=conve[:,1]
#plot =np.concatenate([y_predict[np.newaxis,:],DFT[np.newaxis,:]],axis = 0)
#plot=list((y_predict))
#print(plot[0][0])

d = open('bader_opt.txt', 'w')
for i in y_predict:
    d.write('{:.5f}\n'.format(float(i)))
d.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[66], line 2
#       1 DFT = np.array(target_value)
# ----> 2 predict = np.concatenate((y_pred_train, y_pred_test))
#       3 index= np.concatenate ((train_index, test_index))
#       4 yy = np.array(list(zip(index,predict)))
#
# NameError: name 'y_pred_train' is not defined

# %%
param_grid = {
    'learning_rate': [0.1, 0.01],
     'n_estimators': [50, 100, 150],
     'max_depth': [4, 6],
      'colsample_bytree': [0.7, 0.8, 0.9],
      'subsample': [0.7, 0.8, 0.9],
       'min_child_samples': [1, 5, 10] }

opt_models[model]= lgb.LGBMRegressor(objective='regression', random_state=101)
opt_models[model], cv_score,grid_results = train_model(opt_models[model], param_grid=param_grid, 
                                            X_train=X_train_full,y_train=y_train_full,
                                            X_test=X_test, y_test=y_test,splits=splits, repeats=1)

cv_score.name = model
score_models = score_models.append(cv_score)
# Out:
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [LightGBM] [Warning] Accuracy may be bad since you didn't set num_leaves and 2^max_depth > num_leaves
# [LightGBM] [Warning] Accuracy may be bad since you didn't set num_leaves and 2^max_depth > num_leaves
# [LightGBM] [Warning] Accuracy may be bad since you didn't set num_leaves and 2^max_depth > num_leaves
# [LightGBM] [Warning] Accuracy may be bad since you didn't set num_leaves and 2^max_depth > num_leaves
# [LightGBM] [Warning] Accuracy may be bad since you didn't set num_leaves and 2^max_depth > num_leaves
# [LightGBM] [Warning] Accuracy may be bad since you didn't set num_leaves and 2^max_depth > num_leaves
# [LightGBM] [Warning] Accuracy may be bad since you didn't set num_leaves and 2^max_depth > num_leaves
# [LightGBM] [Warning] Accuracy may be bad since you didn't set num_leaves and 2^max_depth > num_leaves
# ...

# %%
print(y_pred_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 print(y_pred_test)
#
# NameError: name 'y_pred_test' is not defined

# %%
DFT = np.array(target_value)
predict = np.concatenate((y_pred_train, y_pred_test))
index= np.concatenate ((train_index, test_index))
yy = np.array(list(zip(index,predict)))
value=yy[np.lexsort(np.fliplr(yy).T)]
value
conve=np.array(value)
y_predict=conve[:,1]
#plot =np.concatenate([y_predict[np.newaxis,:],DFT[np.newaxis,:]],axis = 0)
#plot=list((y_predict))
#print(plot[0][0])

d = open('bader_opt.txt', 'w')
for i in y_predict:
    d.write('{:.5f}\n'.format(float(i)))
d.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 2
#       1 DFT = np.array(target_value)
# ----> 2 predict = np.concatenate((y_pred_train, y_pred_test))
#       3 index= np.concatenate ((train_index, test_index))
#       4 yy = np.array(list(zip(index,predict)))
#
# NameError: name 'y_pred_train' is not defined

# %%
def rf_feat_importance(m, df):
    return pd.DataFrame({'cols':df.columns, 'imp':m.feature_importances_}
                       ).sort_values('imp', ascending=False)

model = 'AdaBoostRegressor'
fi=rf_feat_importance(opt_models[model],data_frame.iloc[:,:-1])
fi

# %%
def plot_fi(fi):
    return fi.plot('cols', 'imp', 'barh', figsize=(12,7), legend=False)
plot_fi(fi)
# Out:
# <Axes: ylabel='cols'>
